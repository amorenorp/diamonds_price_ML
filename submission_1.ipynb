# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("source/train.csv")

# %%
data
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   1.50    Premium     F     VS2   61.5   58.0  7.32  7.34  4.51
# 1          1   2.01  Very Good     E     SI2   60.6   59.0  8.11  8.25  4.96
# 2          2   0.50      Ideal     E     SI1   61.6   57.0  5.13  5.09  3.15
# 3          3   0.25  Very Good     F    VVS2   61.6   57.0  4.05  4.08  2.50
# 4          4   0.52      Ideal     G     VS2   62.0   55.0  5.16  5.19  3.21
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 40450  40450   1.04  Very Good     I     SI2   59.6   57.0  6.60  6.62  3.94
# 40451  40451   0.51  Very Good     E     SI1   63.3   59.0  5.09  5.05  3.21
# 40452  40452   1.51      Ideal     H     VS2   62.6   57.0  7.37  7.33  4.60
# 40453  40453   2.02    Premium     H     VS2   61.3   60.0  8.16  8.11  4.99
# 40454  40454   0.50       Fair     F     VS2   55.8   60.0  5.31  5.27  2.95
#
#        price
# 0      9.588
# 1      9.748
# 2      7.255
# 3      6.450
# 4      7.721
# ...      ...
# 40450  8.190
# 40451  7.246
# 40452  9.277
# 40453  9.680
# 40454  7.154
#
# [40455 rows x 11 columns]

# %%
data.corr()
# Out:
#              id     carat     depth     table         x         y         z  \
# id     1.000000 -0.006196  0.001098 -0.008829 -0.007112 -0.006420 -0.007766
# carat -0.006196  1.000000  0.025089  0.182590  0.974516  0.950563  0.947930
# depth  0.001098  0.025089  1.000000 -0.300152 -0.028389 -0.032561  0.091421
# table -0.008829  0.182590 -0.300152  1.000000  0.196031  0.184322  0.150142
# x     -0.007112  0.974516 -0.028389  0.196031  1.000000  0.973617  0.965597
# y     -0.006420  0.950563 -0.032561  0.184322  0.973617  1.000000  0.945958
# z     -0.007766  0.947930  0.091421  0.150142  0.965597  0.945958  1.000000
# price -0.006926  0.920878 -0.000924  0.158128  0.957653  0.934700  0.930157
#
#           price
# id    -0.006926
# carat  0.920878
# depth -0.000924
# table  0.158128
# x      0.957653
# y      0.934700
# z      0.930157
# price  1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       40455 non-null  int64
#  1   carat    40455 non-null  float64
#  2   cut      40455 non-null  object
#  3   color    40455 non-null  object
#  4   clarity  40455 non-null  object
#  5   depth    40455 non-null  float64
#  6   table    40455 non-null  float64
#  7   x        40455 non-null  float64
#  8   y        40455 non-null  float64
#  9   z        40455 non-null  float64
#  10  price    40455 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 3.4+ MB

# %%
print(data.cut.unique())
print(data.color.unique())
print(data.clarity.unique())
# Out:
# ['Premium' 'Very Good' 'Ideal' 'Good' 'Fair']
# ['F' 'E' 'G' 'D' 'J' 'I' 'H']
# ['VS2' 'SI2' 'SI1' 'VVS2' 'VS1' 'VVS1' 'IF' 'I1']

# %% [markdown]
# #### En vez de hacer dummies ,  vamos a ver si estas variables float tienen un orden de importancia comparandolas con el precio.

# %%
data["price/carat"]= data["price"] / data["carat"]

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price  \
# 0   0   1.50    Premium     F     VS2   61.5   58.0  7.32  7.34  4.51  9.588
# 1   1   2.01  Very Good     E     SI2   60.6   59.0  8.11  8.25  4.96  9.748
# 2   2   0.50      Ideal     E     SI1   61.6   57.0  5.13  5.09  3.15  7.255
# 3   3   0.25  Very Good     F    VVS2   61.6   57.0  4.05  4.08  2.50  6.450
# 4   4   0.52      Ideal     G     VS2   62.0   55.0  5.16  5.19  3.21  7.721
#
#    price/carat
# 0     6.392000
# 1     4.849751
# 2    14.510000
# 3    25.800000
# 4    14.848077

# %%
print(data.groupby('cut')['price/carat'].mean().sort_values())
print(data.groupby('color')['price/carat'].mean().sort_values())
print(data.groupby('clarity')['price/carat'].mean().sort_values())
# Out:
# cut
# Fair          9.284466
# Good         11.663682
# Premium      11.807049
# Very Good    12.446719
# Ideal        13.893712
# Name: price/carat, dtype: float64
# color
# J     9.017189
# I    10.422280
# H    11.510122
# G    12.992913
# F    13.141893
# D    14.133644
# E    14.300001
# Name: price/carat, dtype: float64
# clarity
# I1       7.466673
# SI2      9.212076
# SI1     11.440938
# VS2     13.008773
# VS1     13.512145
# VVS2    15.815193
# VVS1    17.459082
# IF      17.667809
# Name: price/carat, dtype: float64

# %%
data['cut']=data['cut'].replace({'Ideal':1,'Good':2,'Very Good':3,'Fair':4,'Premium':5})
data['color']=data['color'].replace({'E':1,'D':2,'F':3,'G':4,'H':5,'I':6,'J':7})
data['clarity']=data['clarity'].replace({'VVS1':1,'IF':2,'VVS2':3,'VS1':4,'I1':5,'VS2':6,'SI1':7,'SI2':8})

# %%
data.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price  \
# 0   0   1.50    5      3        6   61.5   58.0  7.32  7.34  4.51  9.588
# 1   1   2.01    3      1        8   60.6   59.0  8.11  8.25  4.96  9.748
# 2   2   0.50    1      1        7   61.6   57.0  5.13  5.09  3.15  7.255
# 3   3   0.25    3      3        3   61.6   57.0  4.05  4.08  2.50  6.450
# 4   4   0.52    1      4        6   62.0   55.0  5.16  5.19  3.21  7.721
#
#    price/carat
# 0     6.392000
# 1     4.849751
# 2    14.510000
# 3    25.800000
# 4    14.848077

# %%
data = data.drop(["price/carat"], axis=1)

# %%
data.corr()
# Out:
#                id     carat       cut     color   clarity     depth     table  \
# id       1.000000 -0.006196 -0.010850  0.002469 -0.002531  0.001098 -0.008829
# carat   -0.006196  1.000000  0.163227  0.289227  0.320217  0.025089  0.182590
# cut     -0.010850  0.163227  1.000000  0.040410  0.164484 -0.087940  0.499487
# color    0.002469  0.289227  0.040410  1.000000 -0.023420  0.044665  0.024083
# clarity -0.002531  0.320217  0.164484 -0.023420  1.000000  0.044650  0.149458
# depth    0.001098  0.025089 -0.087940  0.044665  0.044650  1.000000 -0.300152
# table   -0.008829  0.182590  0.499487  0.024083  0.149458 -0.300152  1.000000
# x       -0.007112  0.974516  0.167382  0.269491  0.343427 -0.028389  0.196031
# y       -0.006420  0.950563  0.150368  0.263042  0.331780 -0.032561  0.184322
# z       -0.007766  0.947930  0.145017  0.265130  0.335356  0.091421  0.150142
# price   -0.006926  0.920878  0.123236  0.159381  0.206736 -0.000924  0.158128
#
#                 x         y         z     price
# id      -0.007112 -0.006420 -0.007766 -0.006926
# carat    0.974516  0.950563  0.947930  0.920878
# cut      0.167382  0.150368  0.145017  0.123236
# color    0.269491  0.263042  0.265130  0.159381
# clarity  0.343427  0.331780  0.335356  0.206736
# depth   -0.028389 -0.032561  0.091421 -0.000924
# table    0.196031  0.184322  0.150142  0.158128
# x        1.000000  0.973617  0.965597  0.957653
# y        0.973617  1.000000  0.945958  0.934700
# z        0.965597  0.945958  1.000000  0.930157
# price    0.957653  0.934700  0.930157  1.000000

# %%
#Quitar ceros en las columas x , y ,z :


# data = data.loc[(data[['x','y','z']]!=0).all(axis=1)]

# %%
data.describe()
# Out:
#                  id         carat           cut         color       clarity  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean   20227.000000      0.796440      2.648177      3.545248      5.516821
# std    11678.496907      0.473467      1.619787      1.767992      2.086539
# min        0.000000      0.200000      1.000000      1.000000      1.000000
# 25%    10113.500000      0.400000      1.000000      2.000000      4.000000
# 50%    20227.000000      0.700000      3.000000      4.000000      6.000000
# 75%    30340.500000      1.040000      5.000000      5.000000      7.000000
# max    40454.000000      5.010000      5.000000      7.000000      8.000000
#
#               depth         table             x             y             z  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean      61.747166     57.455860      5.727615      5.730717      3.536446
# std        1.433123      2.233779      1.121224      1.143828      0.708732
# min       43.000000     43.000000      0.000000      0.000000      0.000000
# 25%       61.000000     56.000000      4.710000      4.720000      2.910000
# 50%       61.800000     57.000000      5.690000      5.700000      3.520000
# 75%       62.500000     59.000000      6.540000      6.540000      4.030000
# max       79.000000     95.000000     10.740000     58.900000     31.800000
#
#               price
# count  40455.000000
# mean       7.782551
# std        1.014333
# min        5.787000
# 25%        6.853000
# 50%        7.779000
# 75%        8.576000
# max        9.843000

# %%
data.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z  price
# 0   0   1.50    5      3        6   61.5   58.0  7.32  7.34  4.51  9.588
# 1   1   2.01    3      1        8   60.6   59.0  8.11  8.25  4.96  9.748
# 2   2   0.50    1      1        7   61.6   57.0  5.13  5.09  3.15  7.255
# 3   3   0.25    3      3        3   61.6   57.0  4.05  4.08  2.50  6.450
# 4   4   0.52    1      4        6   62.0   55.0  5.16  5.19  3.21  7.721

# %% [markdown]
# ### Train - test split

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(["price"], axis =1)
y = data.price

# %%
X_train, X_test, y_train, y_test = train_test_split (X,y, test_size = 0.3, random_state= 100)

# %% [markdown]
# #### Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
model_linear = LinearRegression(n_jobs= -1 )

# %%
model_linear.fit(X_train, y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
y_pred= model_linear.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.21466962246421617

# %%
from sklearn.linear_model import Ridge, Lasso
from sklearn.linear_model import SGDRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LogisticRegression

# %%
models = {
    "ridge":Ridge(),
    "lasso":Lasso(),
    "sgd":SGDRegressor(),
    "knn": KNeighborsRegressor(),
    "gradient":GradientBoostingRegressor(),
    "svr": SVR(),
    "linear": LinearRegression()
}

# %%
for m in models.values():
    m.fit(X_train,y_train)

# %%
y_pred = {}

for name,m in models.items():
    y_pred[name] = m.predict(X_test)

# %%
mse = {}
for name,y in y_pred.items():
    mse[name] = mean_squared_error(y,y_test)

# %%
mse
# Out:
# {'ridge': 0.21316650296705683,
#  'lasso': 0.8658570378183909,
#  'sgd': 7.302871725802479e+30,
#  'knn': 0.9108990676641674,
#  'gradient': 0.012792712705956558,
#  'svr': 1.018374759612243,
#  'linear': 0.21466962246421617}

# %%
#KNeighbors

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
kneighbors = KNeighborsRegressor(n_jobs= -1)

# %%
kneighbors.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1)

# %%
y_pred = kneighbors.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.9108990676641674

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_jobs= -1)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
y_pred = rf.predict(X_test)

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.010004974205380242

# %%
y_pred
# Out:
# array([6.77186, 9.61061, 6.71601, ..., 6.83067, 7.64268, 8.23717])

# %%
## Diamonds TEST

# %%
data_test = pd.read_csv("source/test.csv")

# %%
data_test.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z
# 0   0   0.51  Very Good     E     SI2   58.3   61.9  5.19  5.20  3.04
# 1   1   1.02  Very Good     F     SI2   63.0   58.0  6.37  6.43  4.03
# 2   2   0.59      Ideal     D     VS2   61.9   56.0  5.39  5.34  3.32
# 3   3   0.90  Very Good     D     VS2   62.3   56.0  6.14  6.18  3.84
# 4   4   2.01    Premium     J     VS1   60.2   61.0  8.23  8.16  4.93

# %%
data_test['cut']=data_test['cut'].replace({'Ideal':1,'Good':2,'Very Good':3,'Fair':4,'Premium':5})
data_test['color']=data_test['color'].replace({'E':1,'D':2,'F':3,'G':4,'H':5,'I':6,'J':7})
data_test['clarity']=data_test['clarity'].replace({'VVS1':1,'IF':2,'VVS2':3,'VS1':4,'I1':5,'VS2':6,'SI1':7,'SI2':8})

# %%
# data_test = data_test.loc[(data_test[['x','y','z']]!=0).all(axis=1)]

# %%
data_test.describe()
# Out:
#                  id         carat           cut         color       clarity  \
# count  13485.000000  13485.000000  13485.000000  13485.000000  13485.000000
# mean    6742.000000      0.802440      2.660141      3.516945      5.501965
# std     3892.928525      0.475629      1.615232      1.767303      2.108788
# min        0.000000      0.200000      1.000000      1.000000      1.000000
# 25%     3371.000000      0.400000      1.000000      2.000000      4.000000
# 50%     6742.000000      0.710000      3.000000      4.000000      6.000000
# 75%    10113.000000      1.040000      5.000000      5.000000      7.000000
# max    13484.000000      4.000000      5.000000      7.000000      8.000000
#
#               depth         table             x             y             z
# count  13485.000000  13485.000000  13485.000000  13485.000000  13485.000000
# mean      61.756122     57.461157      5.741783      5.745953      3.545598
# std        1.431146      2.236702      1.123344      1.137006      0.696500
# min       52.700000     49.000000      0.000000      0.000000      0.000000
# 25%       61.000000     56.000000      4.720000      4.730000      2.920000
# 50%       61.800000     57.000000      5.710000      5.720000      3.530000
# 75%       62.500000     59.000000      6.540000      6.540000      4.040000
# max       79.000000     79.000000     10.010000     31.800000      6.380000

# %%
data_test.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z
# 0   0   0.51    3      1        8   58.3   61.9  5.19  5.20  3.04
# 1   1   1.02    3      3        8   63.0   58.0  6.37  6.43  4.03
# 2   2   0.59    1      2        6   61.9   56.0  5.39  5.34  3.32
# 3   3   0.90    3      2        6   62.3   56.0  6.14  6.18  3.84
# 4   4   2.01    5      7        4   60.2   61.0  8.23  8.16  4.93

# %%
### 

test_predictions = rf.predict(data_test)

# %%
test_ID = data_test["id"]

submission_1 = pd.DataFrame({
    "id": test_ID,
    "Price": test_predictions
})

# %%
submission_1
# Out:
#           id    Price
# 0          0  7.03146
# 1          1  8.33099
# 2          2  7.59575
# 3          3  8.45020
# 4          4  9.57338
# ...      ...      ...
# 13480  13480  8.50390
# 13481  13481  6.45961
# 13482  13482  6.59444
# 13483  13483  6.76029
# 13484  13484  8.15159
#
# [13485 rows x 2 columns]

# %%
submission_1.to_csv('submission_1.csv', index=False, header = True)
